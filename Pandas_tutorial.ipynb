# %%
import pandas as pd

# %%
# load csv file 
df = pd.read_csv("pokemon_data .csv") # COPY PATH
# print csv data
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# first 5 rows
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#last 3 rows
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df = pd.read_csv("pokemon_data .csvt", delimiter = '\t')
print(df.head(4))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# Read headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#Read single column
print(df['Name'][0:6])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# 5               Charmeleon
# Name: Name, dtype: object

# %%
#Read multiple column
print(df[['Name','HP']])
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
print(df.iloc[1:3])
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2   Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 1           1      False
# 2           1      False

# %%
#access data using index values, [row,col]
print(df.iloc[1,1])
# Out:
# Ivysaur

# %%
# access using label
print(df.loc[:,'HP'])
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
#access data using multiple labels with conditions. 
print(df.loc[(df['Type 2'] == "Fighting") & (df['HP'] < 70)])
# Out:
#        #                 Name   Type 1    Type 2  HP  Attack  Defense  \
# 277  256            Combusken     Fire  Fighting  60      85       60
# 310  286              Breloom    Grass  Fighting  60     130       80
# 436  391             Monferno     Fire  Fighting  64      78       52
# 476  428  LopunnyMega Lopunny   Normal  Fighting  65     136       94
# 503  453             Croagunk   Poison  Fighting  48      61       40
# 526  475              Gallade  Psychic  Fighting  68     125       65
# 527  475  GalladeMega Gallade  Psychic  Fighting  68     165       95
# 620  559              Scraggy     Dark  Fighting  50      75       70
# 621  560              Scrafty     Dark  Fighting  65      90      115
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 277       85       60     55           3      False
# 310       60       60     70           3      False
# 436       78       52     81           4      False
# 476       54       96    135           4      False
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# df.sort_values(['Speed','Name'], ascending = [False,True])
df.sort_values(['Speed','Name'], ascending = [0,1])
# Out:
#        #                       Name   Type 1  Type 2   HP  Attack  Defense  \
# 431  386          DeoxysSpeed Forme  Psychic     NaN   50      95       90
# 315  291                    Ninjask      Bug  Flying   61      90       45
# 154  142  AerodactylMega Aerodactyl     Rock  Flying   80     135       85
# 71    65      AlakazamMega Alakazam  Psychic     NaN   55      50       65
# 429  386         DeoxysAttack Forme  Psychic     NaN   50     180       20
# ..   ...                        ...      ...     ...  ...     ...      ...
# 486  438                     Bonsly     Rock     NaN   50      80       95
# 658  597                  Ferroseed    Grass   Steel   44      50       91
# 359  328                   Trapinch   Ground     NaN   45     100       45
# 495  446                   Munchlax   Normal     NaN  135      85       40
# 230  213                    Shuckle      Bug    Rock   20      10      230
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#New column
df['Total'] = df['HP'] + df['Attack'] + df['Speed']
print(df.head(6))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    139
# 1       80     60           1      False    182
# 2      100     80           1      False    242
# 3      120     80           1      False    260
# 4       50     65           1      False    156
# 5       65     80           1      False    202

# %%
# Max of total and print the row
# idxmax() - index of max value
#loc[df[index_max]] gives row with that index
print(df.loc[df['Total'].idxmax()])
# Out:
# #                             150
# Name          MewtwoMega Mewtwo X
# Type 1                    Psychic
# Type 2                   Fighting
# HP                            106
# Attack                        190
# Defense                       100
# Sp. Atk                       154
# Sp. Def                       100
# Speed                         130
# Generation                      1
# Legendary                    True
# Total                         426
# Name: 163, dtype: object

# %%
print(df.loc[df['Total'].idxmin()])
# Out:
# #                 213
# Name          Shuckle
# Type 1            Bug
# Type 2           Rock
# HP                 20
# Attack             10
# Defense           230
# Sp. Atk            10
# Sp. Def           230
# Speed               5
# Generation          2
# Legendary       False
# Total              35
# Name: 230, dtype: object

# %%
# Top 5 rows (max)
print(df.nlargest(5, 'Total')[['Name', 'Total', 'Speed']])
# Out:
#                       Name  Total  Speed
# 163    MewtwoMega Mewtwo X    426    130
# 313                Slaking    410    100
# 426  RayquazaMega Rayquaza    400    115
# 164    MewtwoMega Mewtwo Y    396    140
# 711     KyuremBlack Kyurem    390     95

# %%
print(df.nsmallest(5, 'Total')[['Name', 'Total', 'Speed']])
# Out:
#           Name  Total  Speed
# 230    Shuckle     35      5
# 189     Togepi     75     20
# 388    Duskull     85     25
# 446  Kricketot     87     25
# 187     Cleffa     90     15

# %%
# Drop columns
df = df.drop(columns = ['Generation', 'Defense'])
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Sp. Def  \
# 0      1              Bulbasaur    Grass  Poison  45      49       65
# 1      2                Ivysaur    Grass  Poison  60      62       80
# 2      3               Venusaur    Grass  Poison  80      82      100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      120
# 4      4             Charmander     Fire     NaN  39      52       50
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110      130
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160      130
# 799  721              Volcanion     Fire   Water  80     110       90
#
#      Legendary  Total
# 0        False    139
# 1        False    182
# 2        False    242
# 3        False    260
# ...

# %%
df['Power'] = df.iloc[:, 4:6].sum(axis = 1)
print(df[['Name','HP','Power']])
# Out:
#                       Name  HP  Power
# 0                Bulbasaur  45     94
# 1                  Ivysaur  60    122
# 2                 Venusaur  80    162
# 3    VenusaurMega Venusaur  80    180
# 4               Charmander  39     91
# ..                     ...  ..    ...
# 795                Diancie  50    150
# 796    DiancieMega Diancie  50    210
# 797    HoopaHoopa Confined  80    190
# 798     HoopaHoopa Unbound  80    240
# 799              Volcanion  80    190
#
# [800 rows x 3 columns]

# %%
l= df.columns.values
print(list)
print(df[l[3:6]])
# Out:
# ['#' 'Name' 'Type 1' 'Type 2' 'HP' 'Attack' 'Sp. Def' 'Legendary' 'Total'
#  'Power']
#      Type 2  HP  Attack
# 0    Poison  45      49
# 1    Poison  60      62
# 2    Poison  80      82
# 3    Poison  80     100
# 4       NaN  39      52
# ..      ...  ..     ...
# 795   Fairy  50     100
# 796   Fairy  50     160
# 797   Ghost  80     110
# 798    Dark  80     160
# 799   Water  80     110
#
# [800 rows x 3 columns]

# %%
#save as new csv file with updates.
df.to_csv('modified.csv', index = False)
df.to_csv('modified.txt', index = False, sep = '\t')

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] < 90)]
print(new_df)
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Sp. Def  \
# 0      1              Bulbasaur  Grass  Poison  45      49       65
# 1      2                Ivysaur  Grass  Poison  60      62       80
# 2      3               Venusaur  Grass  Poison  80      82      100
# 3      3  VenusaurMega Venusaur  Grass  Poison  80     100      120
# 48    43                 Oddish  Grass  Poison  45      50       65
# 49    44                  Gloom  Grass  Poison  60      65       75
# 50    45              Vileplume  Grass  Poison  75      80       90
# 75    69             Bellsprout  Grass  Poison  50      75       30
# 76    70             Weepinbell  Grass  Poison  65      90       45
# 77    71             Victreebel  Grass  Poison  80     105       70
# 344  315                Roselia  Grass  Poison  50      60       80
# 451  406                  Budew  Grass  Poison  40      30       70
# 452  407               Roserade  Grass  Poison  60      70      105
# ...

# %%
# Assign values to index in order.
new_df = new_df.reset_index(drop =True)
print(new_df)
# Out:
#     index    #                   Name Type 1  Type 2  HP  Attack  Sp. Def  \
# 0       0    1              Bulbasaur  Grass  Poison  45      49       65
# 1       1    2                Ivysaur  Grass  Poison  60      62       80
# 2       2    3               Venusaur  Grass  Poison  80      82      100
# 3       3    3  VenusaurMega Venusaur  Grass  Poison  80     100      120
# 4      48   43                 Oddish  Grass  Poison  45      50       65
# 5      49   44                  Gloom  Grass  Poison  60      65       75
# 6      50   45              Vileplume  Grass  Poison  75      80       90
# 7      75   69             Bellsprout  Grass  Poison  50      75       30
# 8      76   70             Weepinbell  Grass  Poison  65      90       45
# 9      77   71             Victreebel  Grass  Poison  80     105       70
# 10    344  315                Roselia  Grass  Poison  50      60       80
# 11    451  406                  Budew  Grass  Poison  40      30       70
# ...

# %%
# print(df.loc[~df['Name'].str.contains('Scizor')])
print(df.loc[df['Name'].str.contains('Scizor')])
# Out:
#        #               Name Type 1 Type 2  HP  Attack  Sp. Def  Legendary  \
# 228  212             Scizor    Bug  Steel  70     130       80      False
# 229  212  ScizorMega Scizor    Bug  Steel  70     150      100      False
#
#      Total  Power
# 228    265    200
# 229    295    220

# %%
# REGREX
import re
# Type is either Fire or Grass
df.loc[df['Type 1'].str.contains('Fire|Grass', flags = re.I, regex = True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Sp. Def  \
# 0      1              Bulbasaur  Grass  Poison   45      49       65
# 1      2                Ivysaur  Grass  Poison   60      62       80
# 2      3               Venusaur  Grass  Poison   80      82      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      120
# 4      4             Charmander   Fire     NaN   39      52       50
# ..   ...                    ...    ...     ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       54
# 736  668                 Pyroar   Fire  Normal   86      68       66
# 740  672                 Skiddo  Grass     NaN   66      65       57
# 741  673                 Gogoat  Grass     NaN  123     100       81
# 799  721              Volcanion   Fire   Water   80     110       90
#
#      Legendary  Total  Power
# 0        False    139     94
# 1        False    182    122
# 2        False    242    162
# ...

# %%
# Name have 'pi'
df.loc[df['Name'].str.contains('pi[a-z]*', flags = re.I, regex = True)]
# Out:
#        #                     Name    Type 1    Type 2   HP  Attack  Sp. Def  \
# 13    10                 Caterpie       Bug       NaN   45      30       20
# 20    16                   Pidgey    Normal    Flying   40      45       35
# 21    17                Pidgeotto    Normal    Flying   63      60       50
# 22    18                  Pidgeot    Normal    Flying   83      80       70
# 23    18      PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25                  Pikachu  Electric       NaN   35      55       50
# 42    37                   Vulpix      Fire       NaN   38      41       65
# 76    70               Weepinbell     Grass    Poison   65      90       45
# 84    78                 Rapidash      Fire       NaN   65     100       80
# 136  127                   Pinsir       Bug       NaN   65     125       70
# 137  127        PinsirMega Pinsir       Bug    Flying   65     155       90
# ...

# %%
#Name starts with 'pi' (^ - start)
df.loc[df['Name'].str.contains('^pi[a-z]*', flags = re.I, regex = True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Sp. Def  \
# 20    16               Pidgey    Normal    Flying   40      45       35
# 21    17            Pidgeotto    Normal    Flying   63      60       50
# 22    18              Pidgeot    Normal    Flying   83      80       70
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       50
# 136  127               Pinsir       Bug       NaN   65     125       70
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155       90
# 186  172                Pichu  Electric       NaN   20      40       35
# 219  204               Pineco       Bug       NaN   50      65       35
# 239  221            Piloswine       Ice    Ground  100     100       60
# 438  393               Piplup     Water       NaN   53      51       56
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
df.loc[df['HP'] <50, ['Power', 'Total']] = 'CHECK'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Sp. Def  \
# 0      1              Bulbasaur    Grass  Poison  45      49       65
# 1      2                Ivysaur    Grass  Poison  60      62       80
# 2      3               Venusaur    Grass  Poison  80      82      100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      120
# 4      4             Charmander     Fire     NaN  39      52       50
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110      130
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160      130
# 799  721              Volcanion     Fire   Water  80     110       90
#
#     Legendary  Total  Power
# 0       Check  CHECK  CHECK
# 1       False    182    122
# 2       False    242    162
# ...

# %%
df.groupby(['Name']).mean(numeric_only=True).sort_values('HP', ascending = False)
# Out:
#                #     HP  Attack  Sp. Def
# Name
# Blissey    242.0  255.0    10.0    135.0
# Chansey    113.0  250.0     5.0    105.0
# Wobbuffet  202.0  190.0    33.0     58.0
# Wailord    321.0  170.0    90.0     45.0
# Alomomola  594.0  165.0    75.0     45.0
# ...          ...    ...     ...      ...
# Mime Jr.   439.0   20.0    25.0     90.0
# Shuckle    213.0   20.0    10.0    230.0
# Pichu      172.0   20.0    40.0     35.0
# Diglett     50.0   10.0    55.0     45.0
# Shedinja   292.0    1.0    90.0     30.0
#
# [800 rows x 4 columns]

# %%
df.groupby(['Name']).sum(numeric_only=True).sort_values('HP', ascending = False)
# Out:
#              #   HP  Attack  Sp. Def
# Name
# Blissey    242  255      10      135
# Chansey    113  250       5      105
# Wobbuffet  202  190      33       58
# Wailord    321  170      90       45
# Alomomola  594  165      75       45
# ...        ...  ...     ...      ...
# Mime Jr.   439   20      25       90
# Shuckle    213   20      10      230
# Pichu      172   20      40       35
# Diglett     50   10      55       45
# Shedinja   292    1      90       30
#
# [800 rows x 4 columns]

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  Attack  Sp. Def  Legendary  Total  Power
# Type 1
# Bug        69    69      52   69      69       69         69     69     69
# Dark       31    31      21   31      31       31         31     31     31
# Dragon     32    32      21   32      32       32         32     32     32
# Electric   44    44      17   44      44       44         44     44     44
# Fairy      17    17       2   17      17       17         17     17     17
# Fighting   27    27       7   27      27       27         27     27     27
# Fire       52    52      24   52      52       52         52     52     52
# Flying      4     4       2    4       4        4          4      4      4
# Ghost      32    32      22   32      32       32         32     32     32
# Grass      70    70      37   70      70       70         70     70     70
# Ground     32    32      19   32      32       32         32     32     32
# ...

# %%
df.groupby(['Type 1'])['Name'].count()
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Name, dtype: int64

# %%
df.groupby(['Type 1'])['HP'].mean()
# Out:
# Type 1
# Bug         56.884058
# Dark        66.806452
# Dragon      83.312500
# Electric    59.795455
# Fairy       74.117647
# Fighting    69.851852
# Fire        69.903846
# Flying      70.750000
# Ghost       64.437500
# Grass       67.271429
# Ground      73.781250
# Ice         72.000000
# Normal      77.275510
# Poison      67.250000
# Psychic     70.631579
# Rock        65.363636
# Steel       65.222222
# Water       72.062500
# Name: HP, dtype: float64

# %% [markdown]
# #### DATA HANDLING

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Sp. Def Legendary  \
# 0  1              Bulbasaur  Grass  Poison  45      49       65     Check
# 1  2                Ivysaur  Grass  Poison  60      62       80     False
# 2  3               Venusaur  Grass  Poison  80      82      100     False
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      120     False
# 4  4             Charmander   Fire     NaN  39      52       50     Check
#
#    Total  Power
# 0  CHECK  CHECK
# 1    182    122
# 2    242    162
# 3    260    180
# 4  CHECK  CHECK

# %%
df.tail(6)
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Sp. Def  \
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100       95
# 795  719              Diancie     Rock   Fairy   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110      130
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160      130
# 799  721            Volcanion     Fire   Water   80     110       90
#
#     Legendary Total Power
# 794      True   303   208
# 795      True   200   150
# 796      True   320   210
# 797      True   260   190
# 798      True   320   240
# 799      True   260   190

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          800 non-null    int64
#  1   Name       800 non-null    object
#  2   Type 1     800 non-null    object
#  3   Type 2     414 non-null    object
#  4   HP         800 non-null    int64
#  5   Attack     800 non-null    int64
#  6   Sp. Def    800 non-null    int64
#  7   Legendary  800 non-null    object
#  8   Total      800 non-null    object
#  9   Power      800 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 62.6+ KB

# %%
# DROP MISSING VALUES
df = df.dropna()
#Fill missing value
df['HP'] = df['HP'].fillna(0)

# %%
#Drop columns
df = df.drop(columns = 'Sp. Def')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack Legendary  Total  \
# 0      1              Bulbasaur    Grass  Poison  45      49     Check  CHECK
# 1      2                Ivysaur    Grass  Poison  60      62     False    182
# 2      3               Venusaur    Grass  Poison  80      82     False    242
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100     False    260
# 6      6              Charizard     Fire  Flying  78      84     False    262
# ..   ...                    ...      ...     ...  ..     ...       ...    ...
# 795  719                Diancie     Rock   Fairy  50     100      True    200
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      True    320
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110      True    260
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160      True    320
# 799  721              Volcanion     Fire   Water  80     110      True    260
#
#      Power
# 0    CHECK
# ...

# %%
#if only want to read specific columns from file
df = pd.read_csv('data.csv', usecols=['Name', 'HP'])

# %%
#no of rows and columns
df.shape
# Out:
# (414, 9)

# %%
df.columns.values
# Out:
# array(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Legendary',
#        'Total', 'Power'], dtype=object)

# %%
#remove rows only where value of HP is null
df = df.dropna(subset = ['HP'])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack Legendary  Total  \
# 0      1              Bulbasaur    Grass  Poison  45      49     Check  CHECK
# 1      2                Ivysaur    Grass  Poison  60      62     False    182
# 2      3               Venusaur    Grass  Poison  80      82     False    242
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100     False    260
# 6      6              Charizard     Fire  Flying  78      84     False    262
# ..   ...                    ...      ...     ...  ..     ...       ...    ...
# 795  719                Diancie     Rock   Fairy  50     100      True    200
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      True    320
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110      True    260
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160      True    320
# 799  721              Volcanion     Fire   Water  80     110      True    260
#
#      Power
# 0    CHECK
# ...

# %%
#Rename column Name
df.rename(columns = {'Power':'BOOST'}, inplace = True)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack Legendary  Total  \
# 0      1              Bulbasaur    Grass  Poison  45      49     Check  CHECK
# 1      2                Ivysaur    Grass  Poison  60      62     False    182
# 2      3               Venusaur    Grass  Poison  80      82     False    242
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100     False    260
# 6      6              Charizard     Fire  Flying  78      84     False    262
# ..   ...                    ...      ...     ...  ..     ...       ...    ...
# 795  719                Diancie     Rock   Fairy  50     100      True    200
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      True    320
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110      True    260
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160      True    320
# 799  721              Volcanion     Fire   Water  80     110      True    260
#
#      BOOST
# 0    CHECK
# ...

# %%
#Change datatype
df['HP'] = df['HP'].astype('int')

# %%
#show duplicated values
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Legendary, Total, BOOST]
# Index: []

# %%
#drop rows which have duplicate values 
df.drop_duplicates(inplace = True )

# %%
#drop rows which have duplicated Names 
df.drop_duplicates(subset = ['Name'],inplace = True )

# %%
df.reset_index(drop = True)
# Out:
#      level_0  index    #                   Name   Type 1  Type 2  HP  Attack  \
# 0          0      0    1              Bulbasaur    Grass  Poison  45      49
# 1          1      1    2                Ivysaur    Grass  Poison  60      62
# 2          2      2    3               Venusaur    Grass  Poison  80      82
# 3          3      3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4          4      6    6              Charizard     Fire  Flying  78      84
# ..       ...    ...  ...                    ...      ...     ...  ..     ...
# 409      409    795  719                Diancie     Rock   Fairy  50     100
# 410      410    796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 411      411    797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 412      412    798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 413      413    799  721              Volcanion     Fire   Water  80     110
#
#     Legendary  Total  BOOST
# ...
